# %% [markdown]
# [![Open In Colab](https://github.com/MonashDataFluency/python-web-scraping/blob/master/images/colab-badge.svg?raw=1)](https://colab.research.google.com/github/MonashDataFluency/python-web-scraping/blob/master/notebooks/section-3-API-based-scraping.ipynb)

# %% [markdown]
# <img src="https://github.com/MonashDataFluency/python-web-scraping/blob/master/images/api.png?raw=1">

# %% [markdown]
# ### A brief introduction to APIs
# ---

# %% [markdown]
# In this section, we will take a look at an alternative way to gather data than the previous pattern based HTML scraping. Sometimes websites offer an API (or Application Programming Interface) as a service which provides a high level interface to directly retrieve data from their repositories or databases at the backend.
#
# From Wikipedia,
#
# > "*An API is typically defined as a set of specifications, such as Hypertext Transfer Protocol (HTTP) request messages, along with a definition of the structure of response messages, usually in an Extensible Markup Language (XML) or JavaScript Object Notation (JSON) format.*"
#
# They typically tend to be URL endpoints (to be fired as requests) that need to be modified based on our requirements (what we desire in the response body) which then returns some a payload (data) within the response, formatted as either JSON, XML or HTML.
#
# A popular web architecture style called `REST` (or representational state transfer) allows users to interact with web services via `GET` and `POST` calls (two most commonly used) which we briefly saw in the previous section.
#
# For example, Twitter's REST API allows developers to access core Twitter data and the Search API provides methods for developers to interact with Twitter Search and trends data.
#
# There are primarily two ways to use APIs :
#
# - Through the command terminal using URL endpoints, or
# - Through programming language specific *wrappers*
#
# For example, `Tweepy` is a famous python wrapper for Twitter API whereas `twurl` is a command line interface (CLI) tool but both can achieve the same outcomes.
#
# Here we focus on the latter approach and will use a Python library (a wrapper) called `wptools` based around the original MediaWiki API.
#
# One advantage of using official APIs is that they are usually compliant of the terms of service (ToS) of a particular service that researchers are looking to gather data from. However, third-party libraries or packages which claim to provide more throughput than the official APIs (rate limits, number of requests/sec) generally operate in a gray area as they tend to violate ToS. Always be sure to read their documentation throughly.

# %% [markdown]
# ### Wikipedia API
# ---

# %% [markdown]
# Let's say we want to gather some additional data about the Fortune 500 companies and since wikipedia is a rich source for data we decide to use the MediaWiki API to scrape this data. One very good place to start would be to look at the **infoboxes** (as wikipedia defines them) of articles corresponsing to each company on the list. They essentially contain a wealth of metadata about a particular entity the article belongs to which in our case is a company.
#
# For e.g. consider the wikipedia article for **Walmart** (https://en.wikipedia.org/wiki/Walmart) which includes the following infobox :
#
# ![An infobox](https://github.com/MonashDataFluency/python-web-scraping/blob/master/images/infobox.png?raw=1)
#
# As we can see from above, the infoboxes could provide us with a lot of valuable information such as :
#
# - Year of founding
# - Industry
# - Founder(s)
# - Products
# - Services
# - Operating income
# - Net income
# - Total assets
# - Total equity
# - Number of employees etc
#
# Although we expect this data to be fairly organized, it would require some post-processing which we will tackle in our next section. We pick a subset of our data and focus only on the top **20** of the Fortune 500 from the full list.
#
# Let's begin by installing some of libraries we will use for this excercise as follows,

# %%
# sudo apt install libcurl4-openssl-dev libssl-dev
# !pip install wptools
# !pip install wikipedia
# !pip install wordcloud
# Out:
# Collecting wptools
#   Downloading wptools-0.4.17-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from wptools) (2024.8.30)
# Collecting html2text (from wptools)
#   Downloading html2text-2024.2.26.tar.gz (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from wptools) (4.9.4)
# Collecting pycurl (from wptools)
#   Downloading pycurl-7.45.3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Downloading wptools-0.4.17-py2.py3-none-any.whl (38 kB)
# Downloading pycurl-7.45.3-cp310-cp310-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 21.3 MB/s eta 0:00:00
# Building wheels for collected packages: html2text
#   Building wheel for html2text (setup.py) ... done
#   Created wheel for html2text: filename=html2text-2024.2.26-py3-none-any.whl size=33111 sha256=a1041a729c25f4e549f6395c720fc077c59cf7b23a6c465d4bfbdf9eb494b55a
#   Stored in directory: /root/.cache/pip/wheels/f3/96/6d/a7eba8f80d31cbd188a2787b81514d82fc5ae6943c44777659
# Successfully built html2text
# Installing collected packages: pycurl, html2text, wptools
# Successfully installed html2text-2024.2.26 pycurl-7.45.3 wptools-0.4.17
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->wikipedia) (2.6)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11679 sha256=ca41958e2f82e97e126a0f9f25e8be73f9a353733a89f7e4d3d5a2ee3529e52e
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# Importing the same,

# %%
import json
import wptools
import wikipedia
import pandas as pd

print('wptools version : {}'.format(wptools.__version__)) # checking the installed version
# Out:
# wptools version : 0.4.17

# %% [markdown]
# Now let's load the data which we scrapped in the previous section as follows,

# %%
# If you dont have the file, you can use the below code to fetch it:
import urllib.request
url = 'https://raw.githubusercontent.com/MonashDataFluency/python-web-scraping/master/data/fortune_500_companies.csv'
urllib.request.urlretrieve(url, 'fortune_500_companies.csv')
# Out:
# ('fortune_500_companies.csv', <http.client.HTTPMessage at 0x7b021bff1ba0>)

# %%
fname = 'fortune_500_companies.csv' # scrapped data from previous section
df = pd.read_csv(fname)             # reading the csv file as a pandas df
df.head(15)                           # displaying the first 5 rows
# Out:
#     rank        company_name                   company_website
# 0      1             Walmart      http://www.stock.walmart.com
# 1      2         Exxon Mobil         http://www.exxonmobil.com
# 2      3  Berkshire Hathaway  http://www.berkshirehathaway.com
# 3      4               Apple              http://www.apple.com
# 4      5  UnitedHealth Group  http://www.unitedhealthgroup.com
# 5      6            McKesson           http://www.mckesson.com
# 6      7          CVS Health          http://www.cvshealth.com
# 7      8          Amazon.com             http://www.amazon.com
# 8      9                AT&T                http://www.att.com
# 9     10      General Motors                 http://www.gm.com
# 10    11          Ford Motor     http://www.corporate.ford.com
# 11    12   AmerisourceBergen  http://www.amerisourcebergen.com
# 12    13             Chevron            http://www.chevron.com
# 13    14     Cardinal Health     http://www.cardinalhealth.com
# 14    15              Costco             http://www.costco.com

# %% [markdown]
# |    |   rank | company_name       | company_website                  |
# |---:|-------:|:-------------------|:---------------------------------|
# |  0 |      1 | Walmart            | http://www.stock.walmart.com     |
# |  1 |      2 | Exxon Mobil        | http://www.exxonmobil.com        |
# |  2 |      3 | Berkshire Hathaway | http://www.berkshirehathaway.com |
# |  3 |      4 | Apple              | http://www.apple.com             |
# |  4 |      5 | UnitedHealth Group | http://www.unitedhealthgroup.com |

# %% [markdown]
# Let's focus and select only the top 20 companies from the list as follows,

# %%
no_of_companies = 20                         # no of companies we are interested
df_sub = df.iloc[:no_of_companies, :].copy() # only selecting the top 20 companies
companies = df_sub['company_name'].tolist()  # converting the column to a list

# %% [markdown]
# Taking a brief look at the same,

# %%
for i, j in enumerate(companies):   # looping through the list of 20 company
    print('{}. {}'.format(i+1, j))  # printing out the same
# Out:
# 1. Walmart
# 2. Exxon Mobil
# 3. Berkshire Hathaway
# 4. Apple
# 5. UnitedHealth Group
# 6. McKesson
# 7. CVS Health
# 8. Amazon.com
# 9. AT&T
# 10. General Motors
# 11. Ford Motor
# 12. AmerisourceBergen
# 13. Chevron
# 14. Cardinal Health
# 15. Costco
# 16. Verizon
# 17. Kroger
# 18. General Electric
# 19. Walgreens Boots Alliance
# 20. JPMorgan Chase

# %% [markdown]
# ### Getting article names from wiki

# %% [markdown]
# Right off the bat, as you might have guessed, one issue with matching the top 20 Fortune 500 companies to their wikipedia article names is that both of them would not be exactly the same i.e. they match character for character. There will be slight variation in their names.
#
# To overcome this problem and ensure that we have all the company names and its corresponding wikipedia article, we will use the `wikipedia` package to get suggestions for the company names and their equivalent in wikipedia.

# %%
wiki_search = [{company : wikipedia.search(company)} for company in companies]

# %% [markdown]
# Inspecting the same,

# %%
for idx, company in enumerate(wiki_search):
    for i, j in company.items():
        print('{}. {} :\n{}'.format(idx+1, i ,', '.join(j)))
        print('\n')
# Out:
# 1. Walmart :
# Walmart, Criticism of Walmart, History of Walmart, Walmart shooting, Walmarting, Walmart (disambiguation), List of assets owned by Walmart, List of Walmart brands, Walmart Canada, Walmart de México y Centroamérica
#
#
# 2. Exxon Mobil :
# ExxonMobil, Mobil, History of ExxonMobil, Criticism of ExxonMobil, ExxonMobil climate change denial, ExxonMobil Nigeria, Exxon Valdez oil spill, Esso, ExxonMobil Building, Rex Tillerson
#
#
# 3. Berkshire Hathaway :
# Berkshire Hathaway, Berkshire Hathaway Energy, List of assets owned by Berkshire Hathaway, Berkshire Hathaway Assurance, Warren Buffett, List of Berkshire Hathaway publications, Charlie Munger, Ajit Jain, Duracell, The World's Billionaires
#
#
# 4. Apple :
# Apple, Apple Inc., Apple (disambiguation), Apple silicon, Apples to Apples, Apple Watch, Apple Network Server, IPhone, Custard apple, Apple TV
#
#
# 5. UnitedHealth Group :
# UnitedHealth Group, Optum, Richard T. Burke, Change Healthcare, Pharmacy benefit management, Andrew Witty, Stephen J. Hemsley, William W. McGuire, Dhivya Suryadevara, PacifiCare Health Systems
#
#
# 6. McKesson :
# McKesson Corporation, McKesson Europe, McKesson and Robbins scandal, DeRay Mckesson, McKesson (disambiguation), Malcolm McKesson, McKesson Plaza, Precious McKesson, John A. McKesson, III, List of largest companies by revenue
#
#
# 7. CVS Health :
# CVS Health, CVS Pharmacy, CVS Caremark, Karen S. Lynch, Oak Street Health, CVS, Larry Merlo, Aetna, List of largest companies by revenue, Walgreens
#
#
# 8. Amazon.com :
# Amazon (company), Amazon Web Services, Amazon Prime Video, History of Amazon, List of Amazon products and services, IMDb, List of Amazon locations, Amazon S3, Amazon Robotics, Amazon Prime
#
#
# 9. AT&T :
# AT&T, T, AT&T Corporation, T&T, T-54/T-55, AT&T Mobility, Ť, AT-T, T&T Supermarket, Ţ
#
#
# 10. General Motors :
# General Motors, General Motors Vortec engine, History of General Motors, General Motors India, General Motors Canada, General Motors Chapter 11 reorganization, General Motors Kappa platform, General Motors Europe, GMC (marque), General Motors EV1
#
#
# 11. Ford Motor :
# Ford Motor Company, Ford Trimotor, Ford of Britain, Lincoln Motor Company, Henry Ford, Dodge v. Ford Motor Co., History of Ford Motor Company, Ford Germany, Ford Mustang, Edsel Ford
#
#
# 12. AmerisourceBergen :
# Cencora, Cardinal Health, Family Pharmacy, Ornella Barra, Alliance Healthcare, McKesson Corporation, Walgreens Boots Alliance, Fortune 1000, List of largest companies by revenue, Top 100 Contractors of the U.S. federal government
#
#
# 13. Chevron :
# Chevron Corporation, Chevron, Chevron U.S.A., Inc. v. Natural Resources Defense Council, Inc., Chevron (insignia), Chevron Mountain, Steven Donziger, Criticism of Chevron, Wound Chevron, Chevron Phillips Chemical, Loper Bright Enterprises v. Raimondo
#
#
# 14. Cardinal Health :
# Cardinal Health, Cardinal, Catalent, List of largest companies by revenue, Leader Drug Stores, Fortune 500, Cordis (medical), Robert D. Walter, Dublin, Ohio, Top 100 Contractors of the U.S. federal government
#
#
# 15. Costco :
# Costco, Costco hot dog, Costco bear, Costco Wholesale Corp. v. Omega, S. A., James Sinegal, Sol Price, Rotisserie chicken, King Husein, Price Club, Jeffrey Brotman
#
#
# 16. Verizon :
# Verizon, Verizon (mobile network), Verizon Fios, Verizon Business, Visible by Verizon, Yahoo! Inc. (2017–present), Yahoo, TracFone Wireless, Verizon Pennsylvania, Verizon Center
#
#
# 17. Kroger :
# Kroger, Kroger (surname), Proposed acquisition of Albertsons by Kroger, Kroger (disambiguation), Kroger Field, Bernard Kroger, Michael Kroger, Murder Kroger, Collierville Kroger shooting, Kroeger
#
#
# 18. General Electric :
# General Electric, General Electric F404, General Electric GE90, General Electric F110, General Electric CF6, General Electric F118, General Electric LM2500, General Electric GEnx, General Electric GE9X, General Electric F414
#
#
# 19. Walgreens Boots Alliance :
# Walgreens Boots Alliance, Walgreens, Alliance Boots, Boots (company), Stefano Pessina, Alliance Healthcare, Ornella Barra, Rosalind Brewer, No. 7 (brand), Tim Wentworth
#
#
# 20. JPMorgan Chase :
# JPMorgan Chase, Chase Bank, 270 Park Avenue (2021–present), JPMorgan Chase Tower (Houston), Chase Building, 2012 JPMorgan Chase trading loss, Frank (company), Jamie Dimon, 2014 JPMorgan Chase data breach, Bear Stearns

# %% [markdown]
# Now let's get the most probable ones (the first suggestion) for each of the first 20 companies on the Fortune 500 list,

# %%
most_probable = [(company, wiki_search[i][company][0]) for i, company in enumerate(companies)]
companies = [x[1] for x in most_probable]

print(most_probable)
# Out:
# [('Walmart', 'Walmart'), ('Exxon Mobil', 'ExxonMobil'), ('Berkshire Hathaway', 'Berkshire Hathaway'), ('Apple', 'Apple'), ('UnitedHealth Group', 'UnitedHealth Group'), ('McKesson', 'McKesson Corporation'), ('CVS Health', 'CVS Health'), ('Amazon.com', 'Amazon (company)'), ('AT&T', 'AT&T'), ('General Motors', 'General Motors'), ('Ford Motor', 'Ford Motor Company'), ('AmerisourceBergen', 'Cencora'), ('Chevron', 'Chevron Corporation'), ('Cardinal Health', 'Cardinal Health'), ('Costco', 'Costco'), ('Verizon', 'Verizon'), ('Kroger', 'Kroger'), ('General Electric', 'General Electric'), ('Walgreens Boots Alliance', 'Walgreens Boots Alliance'), ('JPMorgan Chase', 'JPMorgan Chase')]

# %% [markdown]
# We can notice that most of the wiki article titles make sense. However, **Apple** is quite ambiguous in this regard as it can indicate the fruit as well as the company. However we can see that the second suggestion returned by was **Apple Inc.**. Hence, we can manually replace it with **Apple Inc.** as follows,

# %%
companies[companies.index('Apple')] = 'Apple Inc.' # replacing "Apple"
print(companies) # final list of wikipedia article titles
# Out:
# ['Walmart', 'ExxonMobil', 'Berkshire Hathaway', 'Apple Inc.', 'UnitedHealth Group', 'McKesson Corporation', 'CVS Health', 'Amazon (company)', 'AT&T', 'General Motors', 'Ford Motor Company', 'Cencora', 'Chevron Corporation', 'Cardinal Health', 'Costco', 'Verizon', 'Kroger', 'General Electric', 'Walgreens Boots Alliance', 'JPMorgan Chase']

# %% [markdown]
# ### Retrieving the infoboxes

# %% [markdown]
# Now that we have mapped the names of the companies to their corresponding wikipedia article let's retrieve the infobox data from those pages.
#
# `wptools` provides easy to use methods to directly call the MediaWiki API on our behalf and get us all the wikipedia data. Let's try retrieving data for **Walmart** as follows,

# %%
page = wptools.page('Walmart')
page.get_parse()    # parses the wikipedia article
# Out:
# en.wikipedia.org (parse) Walmart
# en.wikipedia.org (imageinfo) File:Walmart 7.jpg
# Walmart (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Walmart 7...
#   infobox: <dict(28)> name, logo, image, image_caption, former_nam...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:W...
#   pageid: 33589
#   parsetree: <str(423921)> <root><template><title>Short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Walmart
#   wikibase: Q483551
#   wikidata_url: https://www.wikidata.org/wiki/Q483551
#   wikitext: <str(355676)> {{Short description|American multination...
# }

# %% [markdown]
# As we can see from the output above, `wptools` successfully retrieved the wikipedia and wikidata corresponding to the query **Walmart**. Now inspecting the fetched attributes,

# %%
page.data.keys()
# Out:
# dict_keys(['requests', 'iwlinks', 'pageid', 'wikitext', 'parsetree', 'infobox', 'title', 'wikibase', 'wikidata_url', 'image'])

# %% [markdown]
# The attribute **infobox** contains the data we require,

# %%
page.data['infobox']
# Out:
# {'name': 'Walmart Inc.',
#  'logo': 'Walmart logo.svg',
#  'image': 'Walmart 7.jpg',
#  'image_caption': 'Walmart location in [[Onalaska, Wisconsin]]',
#  'former_name': '{{ubli\n| Wal-Mart Discount City (1962–1969)\n| Wal-Mart, Inc. (1969–1970)\n| Wal-Mart Stores, Inc. (1970–2018)}}',
#  'type': '[[Public company|Public]]',
#  'ISIN': '{{ISIN|sl|=|n|pl|=|y|US9311421039}}',
#  'industry': '[[Retail]]',
#  'predecessor': "Walton's Five and Dime",
#  'traded_as': '{{Unbulleted list|NYSE|WMT|[[DJIA]] component|[[S&P 100]] component|[[S&P 500]] component}} {{NYSE|WMT}}',
#  'foundation': '{{Start date and age|1962|7|2}} , in [[Rogers, Arkansas]]',
#  'founders': '[[Sam Walton]], [[Bud Walton]]',
#  'location_city': '[[Bentonville, Arkansas]]',
#  'location_country': 'United States<br/> {{Coord|36|21|56|N|94|13|03|W|region:US-AR_type:landmark|display|=|title,inline}}',
#  'locations': '10,586 (2022)',
#  'area_served': 'Worldwide',
#  'key_people': '{{plainlist|\n* [[Greg Penner]] ([[chairman]])\n* [[Doug McMillon]] ([[President (corporate title)|president]], [[Chief executive officer|CEO]])}}',
#  'services': '{{hlist|[[Ria Money Transfer|Walmart-2-Walmart]]}}',
#  'revenue': '{{nowrap| |increase| |US$|648.12 billion|link|=|yes| ([[Fiscal Year|FY]]2024)|ref| name=N|{{cite web|url=https://s201.q4cdn.com/262069030/files/doc_financials/2024/ar/2024-annual-report-pdf-final-final.pdf|publisher=Walmart|access-date=February 17, 2022|title=Walmart Annual Report 2023|archive-date=February 21, 2023|archive-url=https://web.archive.org/web/20230221154737/https://s201.q4cdn.com/262069030/files/doc_financials/2023/q4/Earnings-Release-(FY23-Q4)-(final).pdf|url-status=live}}|</ref>|}} {{increase}} {{US$|648.12 billion|link|=|yes}} ([[Fiscal Year|FY]]2024)',
#  'operating_income': '{{Increase}} {{US$|27.0 billion}} (FY2024)',
#  'net_income': '{{Increase}} {{US$|16.27 billion}} (FY2024)',
#  'assets': '{{nowrap| |Increase| |US$|252.399 billion| (FY2024)|ref| name= N|}} {{Increase}} {{US$|252.399 billion}} (FY2024)',
#  'equity': '{{Increase}} {{US$|90.349 billion}} (FY2024)',
#  'owner': '[[Walton family]] (50.85%)',
#  'num_employees': '2,100,000 (Jan. 2024)',
#  'divisions': "{{Unbulleted list|Walmart U.S.|Walmart International|[[Sam's Club]]|Global eCommerce}}",
#  'subsid': '[[List of assets owned by Walmart|List of subsidiaries]]',
#  'homepage': '{{url|https://www.walmart.com/|walmart.com}}'}

# %% [markdown]
# Let's define a list of features that we want from the infoboxes as follows,

# %%
wiki_data = []
# attributes of interest contained within the wiki infoboxes
features = ['founder', 'location_country', 'revenue', 'operating_income', 'net_income', 'assets',
        'equity', 'type', 'industry', 'products', 'num_employees']

# %%
wiki_data
# Out:
# [{'founder': '',
#   'location_country': 'United States<br/> {{Coord|36|21|56|N|94|13|03|W|region:US-AR_type:landmark|display|=|title,inline}}',
#   'revenue': '{{nowrap| |increase| |US$|648.12 billion|link|=|yes| ([[Fiscal Year|FY]]2024)|ref| name=N|{{cite web|url=https://s201.q4cdn.com/262069030/files/doc_financials/2024/ar/2024-annual-report-pdf-final-final.pdf|publisher=Walmart|access-date=February 17, 2022|title=Walmart Annual Report 2023|archive-date=February 21, 2023|archive-url=https://web.archive.org/web/20230221154737/https://s201.q4cdn.com/262069030/files/doc_financials/2023/q4/Earnings-Release-(FY23-Q4)-(final).pdf|url-status=live}}|</ref>|}} {{increase}} {{US$|648.12 billion|link|=|yes}} ([[Fiscal Year|FY]]2024)',
#   'operating_income': '{{Increase}} {{US$|27.0 billion}} (FY2024)',
#   'net_income': '{{Increase}} {{US$|16.27 billion}} (FY2024)',
#   'assets': '{{nowrap| |Increase| |US$|252.399 billion| (FY2024)|ref| name= N|}} {{Increase}} {{US$|252.399 billion}} (FY2024)',
#   'equity': '{{Increase}} {{US$|90.349 billion}} (FY2024)',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Retail]]',
#   'products': '',
#   'num_employees': '2,100,000 (Jan. 2024)',
#   'company_name': 'Walmart'},
#  {'founder': '',
#   'location_country': '',
#   'revenue': '{{nowrap |Decrease| |US$|344.6 billion|link|=|yes| (2023)|sfn|10-K|2023|}} {{Decrease}} {{US$|344.6 billion|link|=|yes}} (2023) {{sfn|10-K|2023}}',
#   'operating_income': '{{nowrap |Decrease| US$52.78 billion (2023)|sfn|10-K|2023|}} {{Decrease}} US$52.78 billion (2023) {{sfn|10-K|2023}}',
#   'net_income': '{{nowrap |Decrease| US$36.01 billion (2023)|sfn|10-K|2023|}} {{Decrease}} US$36.01 billion (2023) {{sfn|10-K|2023}}',
#   'assets': '{{nowrap |Increase| US$376.3 billion (2023)|sfn|10-K|2023|}} {{Increase}} US$376.3 billion (2023) {{sfn|10-K|2023}}',
#   'equity': '{{nowrap |Increase| US$204.8 billion (2023)|sfn|10-K|2023|}} {{Increase}} US$204.8 billion (2023) {{sfn|10-K|2023}}',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Energy industry|Energy]]',
#   'products': '{{Unbulleted list\n  | [[Crude oil]]\n  | [[Oil products]]\n  | [[Natural gas]]\n  | [[Petrochemical]]s\n  | [[Power generation]]}}',
#   'num_employees': '61,500 (2023) {{sfn|10-K|2023}}',
#   'company_name': 'ExxonMobil'},
#  {'founder': '[[Oliver Chace]]',
#   'location_country': '',
#   'revenue': '{{increase}} {{US$|364.5 billion|link|=|yes}} (2023)',
#   'operating_income': '{{increase}} {{US$|120.16 billion}} (2023)',
#   'net_income': '{{increase}} {{US$|96.22 billion}} (2023)',
#   'assets': '{{increase}} {{US$|1.069 trillion}} (2023)',
#   'equity': '{{increase}} {{US$|567.5 billion}} (2023)',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Conglomerate (company)|Conglomerate]]',
#   'products': '{{collapsible list|[[Insurance#Types|Property & casualty insurance]]|[[Reinsurance]]|[[Rail transport]]|[[electric power industry|Electric power]]|[[Natural gas]]|[[Real estate]] services|Industrial parts & materials|[[Mobile home]]s|Building materials|[[Recreational vehicle]]s|[[Apparel]]|[[Retail]] stores & services|[[Aviation]] services|ref|2023 Annual Report, "Item 1: Business Description"|</ref>}}',
#   'num_employees': '396,500 (2023)',
#   'company_name': 'Berkshire Hathaway'},
#  {'founder': '',
#   'location_country': '',
#   'revenue': '{{decrease}} {{US$|383.29}} {{nbsp}} billion',
#   'operating_income': '{{decrease}} {{US$|114.30}} {{nbsp}} billion',
#   'net_income': '{{decrease}} {{US$|97.00}} {{nbsp}} billion',
#   'assets': '{{decrease}} {{US$|352.58}} {{nbsp}} billion',
#   'equity': '{{increase}} {{US$|62.15}} {{nbsp}} billion',
#   'type': '[[Public company|Public]]',
#   'industry': '{{Unbulleted list | [[Consumer electronics]] | [[Software services]] | [[Online services]]}}',
#   'products': '{{flatlist|\n* [[AirPods]]\n* [[Apple TV]]\n* [[Apple Watch]]\n* [[Apple Vision Pro]]\n* [[iPad]]\n* [[iPhone]]\n* [[Macintosh]]}}',
#   'num_employees': '161,000',
#   'company_name': 'Apple Inc.'},
#  {'founder': '[[Richard T. Burke]]',
#   'location_country': '',
#   'revenue': '{{nowrap| |Increase| |US$|371.6 billion|link|=|yes| (2023)}} {{Increase}} {{US$|371.6 billion|link|=|yes}} (2023)',
#   'operating_income': '{{Increase}} {{US$|32.36 billion}} (2023)',
#   'net_income': '{{Increase}} {{US$|23.14 billion}} (2023)',
#   'assets': '{{Increase}} {{US$|273.7 billion}} (2023)',
#   'equity': '{{Increase}} {{US$|94.42 billion}} (2023)',
#   'type': '[[Public company|Public]]',
#   'industry': '{{ubl|[[Managed care|Managed healthcare]]|[[Insurance]]}}',
#   'products': '',
#   'num_employees': '{{circa|440,000}} (2023)',
#   'company_name': 'UnitedHealth Group'},
#  {'founder': '',
#   'location_country': '',
#   'revenue': '{{nowrap|increase| |US$|308.9 billion|link|=|yes| (2024)}} {{increase}} {{US$|308.9 billion|link|=|yes}} (2024)',
#   'operating_income': '{{decrease}} {{US$|3.909 billion}} (2024)',
#   'net_income': '{{decrease}} {{US$|3.002 billion}} (2024)',
#   'assets': '{{increase}} {{US$|67.44 billion}} (2024)',
#   'equity': '{{decrease}} {{US$|-1.97 billion}} (2024)',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Healthcare]]',
#   'products': '{{Unbulleted list|[[Pharmaceuticals]]|[[Medical technology]]|[[Health care services]]}}',
#   'num_employees': '{{circa|51,000}} (2024)',
#   'company_name': 'McKesson Corporation'},
#  {'founder': '',
#   'location_country': '',
#   'revenue': '{{increase}} {{US$|357.8 billion|link|=|yes}} (2023)',
#   'operating_income': '{{increase}} {{US$|13.74 billion}} (2023)',
#   'net_income': '{{increase}} {{US$|8.344 billion}} (2023)',
#   'assets': '{{increase}} {{US$|249.7 billion}} (2023)',
#   'equity': '{{increase}} {{US$|76.64 billion}} (2023)',
#   'type': '[[Public company|Public]]',
#   'industry': '{{Unbulleted list|[[Managed care|Managed healthcare]]|[[Health insurance in the United States|Health insurance]]|[[Pharmacy (shop)|Pharmacy]]}}',
#   'products': '',
#   'num_employees': '{{circa|300,000}} (2023)',
#   'company_name': 'CVS Health'},
#  {'founder': '[[Jeff Bezos]]',
#   'location_country': '',
#   'revenue': '{{increase}} {{US$|574.8}} {{nbsp}} billion',
#   'operating_income': '{{increase}} {{US$|36.85}} {{nbsp}} billion',
#   'net_income': '{{increase}} {{US$|30.43}} {{nbsp}} billion',
#   'assets': '{{increase}} {{US$|527.9}} {{nbsp}} billion',
#   'equity': '{{increase}} {{US$|201.9}} {{nbsp}} billion',
#   'type': '[[Public company|Public]]',
#   'industry': '{{hlist| [[Conglomerate (company)|Conglomerate]]}}',
#   'products': '{{hlist|[[Amazon Echo|Echo]]|[[Amazon Fire tablet|Fire Tablet]]|[[Amazon Fire TV|Fire TV]]|[[Fire OS]]|[[Amazon Kindle|Kindle]]}}',
#   'num_employees': '≈&nbsp;1,525,000',
#   'company_name': 'Amazon (company)'},
#  {'founder': '',
#   'location_country': '',
#   'revenue': '{{increase}} {{US$|122.4|link|=|yes}} billion',
#   'operating_income': '{{increase}} {{US$|23.46}} billion',
#   'net_income': '{{increase}} {{US$|15.62}} billion',
#   'assets': '{{increase}} {{US$|407.1}} billion',
#   'equity': '{{increase}} {{US$|117.4}} billion',
#   'type': '[[Public company|Public]]',
#   'industry': '{{Unbulleted list|[[Telecommunications]]}}',
#   'products': '',
#   'num_employees': '149,900',
#   'company_name': 'AT&T'},
#  {'founder': '[[William C. Durant]]',
#   'location_country': 'United States',
#   'revenue': '{{nowrap|increase| |US$|171.8 billion|link|=|yes| (2023)|ref| name=10K}} {{increase}} {{US$|171.8 billion|link|=|yes}} (2023)',
#   'operating_income': '{{decrease}} US$9.298 billion (2023)',
#   'net_income': '{{decrease}} US$9.840 billion (2023)',
#   'assets': '{{increase}} US$273.1 billion (2023)',
#   'equity': '{{decrease}} US$68.19 billion (2023)',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Automotive industry|Automotive]]',
#   'products': '{{unbulleted list\n  | [[Car|Automobiles]]\n  | [[Performance car|Performance vehicles]]\n  | [[Luxury car|Luxury vehicles]]\n  | [[Commercial vehicle]]s\n  | [[Military vehicles]]\n  | [[Automobile parts]]}}',
#   'num_employees': '163,000 (2023)',
#   'company_name': 'General Motors'},
#  {'founder': '[[Henry Ford]]',
#   'location_country': 'U.S.',
#   'revenue': '{{increase}} {{US$|176.2 billion|link|=|yes}} (2023)',
#   'operating_income': '{{increase}} {{US$|5.46 billion}} (2023)',
#   'net_income': '{{increase}} {{US$|4.33 billion}} (2023)',
#   'assets': '{{increase}} {{US$|273.3 billion}} (2023)',
#   'equity': '{{decrease}} {{US$|42.80 billion}} (2023)',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Automotive industry|Automotive]]',
#   'products': '{{unbulleted list\n  | [[Automobile]]s\n  | [[Performance car|Performance vehicle]]s\n  | [[Luxury vehicle]]s\n  | [[Commercial vehicle]]s\n  | [[List of auto parts|Automotive parts]]}}',
#   'num_employees': '177,000 (2023)',
#   'company_name': 'Ford Motor Company'},
#  {'founder': '',
#   'location_country': '',
#   'revenue': '{{nowrap|increase| |US$|262 billion|link|=|yes| (2023)}} {{increase}} {{US$|262 billion|link|=|yes}} (2023)',
#   'operating_income': '{{decrease}} {{US$|2.34 billion}} (2023)',
#   'net_income': '{{increase}} {{US$|1.75 billion}} (2023)',
#   'assets': '{{nowrap|increase| |US$|62.6 billion| (2023)}} {{increase}} {{US$|62.6 billion}} (2023)',
#   'equity': '{{nowrap|increase| |US$|522 million| (2023)}} {{increase}} {{US$|522 million}} (2023)',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Pharmaceutical]]',
#   'products': '[[Pharmaceutical]]s and [[pharmacy]] services',
#   'num_employees': '{{circa|46,000}} (2023)',
#   'company_name': 'Cencora'},
#  {'founder': '',
#   'location_country': '',
#   'revenue': '{{nowrap| |decrease| |US$|200.9 billion|link|=|yes| (2023)}} {{decrease}} {{US$|200.9 billion|link|=|yes}} (2023)',
#   'operating_income': '{{decrease}} {{US$|29.58 billion}} (2023)',
#   'net_income': '{{decrease}} {{US$|21.37 billion}} (2023)',
#   'assets': '{{increase}} {{US$|261.6 billion}} (2023)',
#   'equity': '{{increase}} {{US$|160.9 billion}} (2023)',
#   'type': '[[Public company|Public]]',
#   'industry': '{{ubl|[[Energy industry|Energy]]|[[Petroleum industry|Oil and gas]]}}',
#   'products': '[[Gasoline]], [[natural gas]] and other [[petrochemical]]s',
#   'num_employees': '45,600 (December 2023)',
#   'company_name': 'Chevron Corporation'},
#  {'founder': '[[Robert D. Walter]]',
#   'location_country': '',
#   'revenue': '{{increase}} {{US$|227 billion|link|=|yes}} (2024)',
#   'operating_income': '{{increase}} {{US$|1.24 billion}} (2024)',
#   'net_income': '{{increase}} {{US$|852 million}} (2024)',
#   'assets': '{{increase}} {{US$|45.1 billion}} (2024)',
#   'equity': '{{decrease}} {{US$|-3.2 billion}} (2024)',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Healthcare]]',
#   'products': 'Medical and pharmaceutical products and services',
#   'num_employees': '48,900 (2024)',
#   'company_name': 'Cardinal Health'},
#  {'founder': '',
#   'location_country': 'US',
#   'revenue': '{{increase}} {{US$|254.5}} {{nbsp}} billion',
#   'operating_income': '{{increase}} {{US$|9.285}} {{nbsp}} billion',
#   'net_income': '{{increase}} {{US$|7.367}} {{nbsp}} billion',
#   'assets': '{{increase}} {{US$|69.83}} {{nbsp}} billion',
#   'equity': '{{decrease}} {{US$|23.62}} {{nbsp}} billion',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Retail]]',
#   'products': '',
#   'num_employees': '{{increase}} 333,000',
#   'company_name': 'Costco'},
#  {'founder': '',
#   'location_country': '',
#   'revenue': '{{decrease}} {{US$|133.97 billion|link|=|yes}}',
#   'operating_income': '{{decrease}} {{US$|22.877 billion}}',
#   'net_income': '{{decrease}} {{US$|12.095 billion}}',
#   'assets': '{{increase}} {{US$|380.26 billion}}',
#   'equity': '{{increase}} {{US$|93.799 billion}}',
#   'type': '[[Public company|Public]]',
#   'industry': '{{Plainlist|\n*[[Telecommunications industry|Telecommunications]]\n*[[Mass media]]}}',
#   'products': '{{Plainlist|\n*[[Cable television]]\n*[[Landline]]\n*[[Mobile phone]]\n*[[Broadband]]\n*[[Digital television]]\n*[[IPTV]]\n*[[Digital Media]]\n*[[Internet of things|Internet]]\n*[[Telematics]]}}',
#   'num_employees': '105,400 (2023)',
#   'company_name': 'Verizon'},
#  {'founder': '[[Bernard Kroger]]',
#   'location_country': 'U.S.',
#   'revenue': '{{nowrap| |increase| |US$|150 billion|link|=|yes| (2023)|ref| name= proxystatement|{{cite web|url=https://www.wsj.com/market-data/quotes/KR/financials/annual/income-statement|title=2022 Kroger Financial Statements|publisher=The Kroger Co|access-date=June 11, 2022|archive-url=https://web.archive.org/web/20161226060558/https://www.google.com/finance?q=NYSE%3AKR&fstype=ii&ei=azu7Vsn8ItfKuATZ9Z_QCg|archive-date=December 26, 2016|url-status=live}}|</ref>|}} {{increase}} {{US$|150 billion|link|=|yes}} (2023)',
#   'operating_income': '{{decrease}} {{US$|3.096 billion}} (2023)',
#   'net_income': '{{increase}} {{US$|2.307 billion}} (2023)',
#   'assets': '{{increase}} {{US$|50.505 billion}} (2023)',
#   'equity': '{{increase}} {{US$|11.601 billion}} (2023)',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Retail]]',
#   'products': '[[Supercenter]]/[[superstore]],<br />Other specialty, [[supermarket]]',
#   'num_employees': '414,000 (2023)',
#   'company_name': 'Kroger'},
#  {'founder': '',
#   'location_country': '',
#   'revenue': '{{increase}} {{US$|68 billion|link|=|yes}} (2023)',
#   'operating_income': '{{increase}} {{US$|9 billion}} (2023)',
#   'net_income': '{{increase}} {{US$|9 billion}} (2023)',
#   'assets': '{{decrease}} {{US$|163 billion}} (2023)',
#   'equity': '{{decrease}} {{US$|29 billion}} (2023)',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Conglomerate (company)|Conglomerate]]',
#   'products': '',
#   'num_employees': '125,000 (2023)',
#   'company_name': 'General Electric'},
#  {'founder': '',
#   'location_country': '',
#   'revenue': '{{nowrap|increase| |US$|147.7&nbsp;billion|link|=|yes| (2024)}} {{increase}} {{US$|147.7&nbsp;billion|link|=|yes}} (2024)',
#   'operating_income': '{{nowrap|decrease| US$–14.1&nbsp;billion (2024)}} {{decrease}} US$–14.1&nbsp;billion (2024)',
#   'net_income': '{{nowrap|decrease| US$–8.64&nbsp;billion (2024)}} {{decrease}} US$–8.64&nbsp;billion (2024)',
#   'assets': '{{nowrap|decrease| US$81.04&nbsp;billion (2024)}} {{decrease}} US$81.04&nbsp;billion (2024)',
#   'equity': '{{nowrap|decrease| US$12.01&nbsp;billion (2024)}} {{decrease}} US$12.01&nbsp;billion (2024)',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Retail industry|Retail]] and [[pharmaceutical industry|pharmaceuticals]]<br />',
#   'products': '',
#   'num_employees': '312,000',
#   'company_name': 'Walgreens Boots Alliance'},
#  {'founder': '',
#   'location_country': '',
#   'revenue': '{{increase}} {{US$|158.1&nbsp;billion|link|=|yes}} (2023)',
#   'operating_income': '',
#   'net_income': '{{increase}} {{US$|49.55 billion}} (2023)',
#   'assets': '{{increase}} {{US$|3.875 trillion}} (2023)',
#   'equity': '{{increase}} {{US$|327.9 billion}} (2023)',
#   'type': '[[Public company|Public]]',
#   'industry': '[[Financial services]]',
#   'products': '{{ubl | [[Asset management]] | [[Banking]] | [[Commodities]] | [[Credit card]]s | [[Equities trading]] | [[Insurance]] | [[Investment management]] | [[Mortgage loan]]s | [[Mutual funds]] | [[Exchange-traded fund]]s | [[Index fund]]s | [[Private equity]] | [[Risk management]] | [[Wealth management]]}}',
#   'num_employees': '309,926',
#   'company_name': 'JPMorgan Chase'}]

# %% [markdown]
# Now fetching the data for all the companies (this may take a while),

# %%
for company in companies:
    page = wptools.page(company) # create a page object
    try:
        page.get_parse() # call the API and parse the data
        if page.data['infobox'] != None:
            # if infobox is present
            infobox = page.data['infobox']
            # get data for the interested features/attributes
            data = { feature : infobox[feature] if feature in infobox else ''
                         for feature in features }
        else:
            data = { feature : '' for feature in features }

        data['company_name'] = company
        wiki_data.append(data)

    except KeyError:
        pass
# Out:
# en.wikipedia.org (parse) Walmart
# en.wikipedia.org (imageinfo) File:Walmart 7.jpg
# Walmart (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Walmart 7...
#   infobox: <dict(28)> name, logo, image, image_caption, former_nam...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:W...
#   pageid: 33589
#   parsetree: <str(423921)> <root><template><title>Short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Walmart
#   wikibase: Q483551
#   wikidata_url: https://www.wikidata.org/wiki/Q483551
#   wikitext: <str(355676)> {{Short description|American multination...
# }
# en.wikipedia.org (parse) ExxonMobil
# en.wikipedia.org (imageinfo) File:Cube xom mine.png
# ExxonMobil (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Cube xom ...
#   infobox: <dict(26)> name, logo, image, image_caption, former_nam...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:E...
#   pageid: 18848197
#   parsetree: <str(108791)> <root><template><title>Short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: ExxonMobil
#   wikibase: Q156238
#   wikidata_url: https://www.wikidata.org/wiki/Q156238
#   wikitext: <str(82417)> {{Short description|American multinationa...
# }
# en.wikipedia.org (parse) Berkshire Hathaway
# en.wikipedia.org (imageinfo) File:OmahaKiewitPlaza.jpg
# Berkshire Hathaway (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:OmahaKiew...
#   infobox: <dict(26)> name, logo, image, image_caption, type, trad...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 314333
#   parsetree: <str(131039)> <root><template><title>short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Berkshire Hathaway
#   wikibase: Q217583
#   wikidata_url: https://www.wikidata.org/wiki/Q217583
#   wikitext: <str(110135)> {{short description|American multination...
# }
# en.wikipedia.org (parse) Apple Inc.
# en.wikipedia.org (imageinfo) File:Aerial view of Apple Park dllu.jpg
# Apple Inc. (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Aerial vi...
#   infobox: <dict(37)> name, logo, logo_caption, image, image_uprig...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Apple_Inc....
#   pageid: 856
#   parsetree: <str(371010)> <root><template><title>Short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Apple Inc.
#   wikibase: Q312
#   wikidata_url: https://www.wikidata.org/wiki/Q312
#   wikitext: <str(308152)> {{Short description|American multination...
# }
# en.wikipedia.org (parse) UnitedHealth Group
# UnitedHealth Group (en) data
# {
#   infobox: <dict(19)> name, logo, type, traded_as, founder, key_pe...
#   pageid: 1845551
#   parsetree: <str(98760)> <root><template><title>Short description...
#   requests: <list(1)> parse
#   title: UnitedHealth Group
#   wikibase: Q2103926
#   wikidata_url: https://www.wikidata.org/wiki/Q2103926
#   wikitext: <str(83099)> {{Short description|American health care ...
# }
# en.wikipedia.org (parse) McKesson Corporation
# McKesson Corporation (en) data
# {
#   infobox: <dict(22)> name, logo, type, traded_as, founders, hq_lo...
#   pageid: 1041603
#   parsetree: <str(51439)> <root><template><title>Short description...
#   requests: <list(1)> parse
#   title: McKesson Corporation
#   wikibase: Q570473
#   wikidata_url: https://www.wikidata.org/wiki/Q570473
#   wikitext: <str(41125)> {{Short description|U.S. healthcare compa...
# }
# en.wikipedia.org (parse) CVS Health
# CVS Health (en) data
# {
#   infobox: <dict(25)> name, logo, logo_size, former_name, type, tr...
#   pageid: 10377597
#   parsetree: <str(72293)> <root><template><title>about</title><par...
#   requests: <list(1)> parse
#   title: CVS Health
#   wikibase: Q624375
#   wikidata_url: https://www.wikidata.org/wiki/Q624375
#   wikitext: <str(58049)> {{about|the parent company previously nam...
# }
# en.wikipedia.org (parse) Amazon (company)
# en.wikipedia.org (imageinfo) File:Amazon Tower I topped out, June...
# Amazon (company) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Amazon To...
#   infobox: <dict(33)> name, logo, image, image_caption, trade_name...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 90451
#   parsetree: <str(195608)> <root><template><title>Short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Amazon (company)
#   wikibase: Q3884
#   wikidata_url: https://www.wikidata.org/wiki/Q3884
#   wikitext: <str(151988)> {{Short description|American multination...
# }
# en.wikipedia.org (parse) AT&T
# en.wikipedia.org (imageinfo) File:AT&THQDallas.jpg
# AT&T (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:AT&THQDal...
#   infobox: <dict(33)> name, logo, image, image_caption, former_nam...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:AT%26T
#   pageid: 17555269
#   parsetree: <str(190922)> <root><template><title>merge from</titl...
#   requests: <list(2)> parse, imageinfo
#   title: AT&T
#   wikibase: Q35476
#   wikidata_url: https://www.wikidata.org/wiki/Q35476
#   wikitext: <str(160338)> {{merge from|AT&T Corporation|discuss=Ta...
# }
# en.wikipedia.org (parse) General Motors
# en.wikipedia.org (imageinfo) File:GM Renaissance Center - Hôtel l...
# General Motors (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:GM Renais...
#   infobox: <dict(30)> name, logo, logo_size, image, image_caption,...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:G...
#   pageid: 12102
#   parsetree: <str(212921)> <root><template><title>Short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: General Motors
#   wikibase: Q81965
#   wikidata_url: https://www.wikidata.org/wiki/Q81965
#   wikitext: <str(162266)> {{Short description|American multination...
# }
# en.wikipedia.org (parse) Ford Motor Company
# en.wikipedia.org (imageinfo) File:FordGlassHouse.jpg
# Ford Motor Company (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:FordGlass...
#   infobox: <dict(29)> name, logo, image, image_caption, type, trad...
#   iwlinks: <list(8)> https://commons.wikimedia.org/wiki/Category:F...
#   pageid: 30433662
#   parsetree: <str(256983)> <root><template><title>Short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Ford Motor Company
#   wikibase: Q44294
#   wikidata_url: https://www.wikidata.org/wiki/Q44294
#   wikitext: <str(218517)> {{Short description|American multination...
# }
# en.wikipedia.org (parse) Cencora
# Cencora (en) data
# {
#   infobox: <dict(20)> name, logo, former_name, type, traded_as, fo...
#   iwlinks: <list(1)> https://foundation.wikimedia.org/wiki/Terms_o...
#   pageid: 1445945
#   parsetree: <str(29493)> <root><template><title>short description...
#   requests: <list(1)> parse
#   title: Cencora
#   wikibase: Q470156
#   wikidata_url: https://www.wikidata.org/wiki/Q470156
#   wikitext: <str(22114)> {{short description|American healthcare c...
# }
# en.wikipedia.org (parse) Chevron Corporation
# en.wikipedia.org (imageinfo) File:Chevron Headquarters 2022.jpg
# Chevron Corporation (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Chevron H...
#   infobox: <dict(29)> name, former_names, logo, logo_size, image, ...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 284749
#   parsetree: <str(126084)> <root><template><title>Short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Chevron Corporation
#   wikibase: Q319642
#   wikidata_url: https://www.wikidata.org/wiki/Q319642
#   wikitext: <str(102089)> {{Short description|American multination...
# }
# en.wikipedia.org (parse) Cardinal Health
# en.wikipedia.org (imageinfo) File:Cardinal Health Headquarters Ae...
# Cardinal Health (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Cardinal ...
#   infobox: <dict(22)> name, logo, image, image_size, image_caption...
#   pageid: 1041632
#   parsetree: <str(38185)> <root><template><title>Short description...
#   requests: <list(2)> parse, imageinfo
#   title: Cardinal Health
#   wikibase: Q902397
#   wikidata_url: https://www.wikidata.org/wiki/Q902397
#   wikitext: <str(29580)> {{Short description|American multinationa...
# }
# en.wikipedia.org (parse) Costco
# en.wikipedia.org (imageinfo) File:Costcoheadquarters.jpg
# Costco (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Costcohea...
#   infobox: <dict(35)> name, logo, logo_size, logo_caption, image, ...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:Costco
#   pageid: 446056
#   parsetree: <str(195723)> <root><template><title>Short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Costco
#   wikibase: Q715583
#   wikidata_url: https://www.wikidata.org/wiki/Q715583
#   wikitext: <str(162862)> {{Short description|American multination...
# }
# en.wikipedia.org (parse) Verizon
# en.wikipedia.org (imageinfo) File:Verizon Building (8156005279).jpg
# Verizon (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Verizon B...
#   infobox: <dict(32)> name, logo, image, image_size, image_caption...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:T...
#   pageid: 18619278
#   parsetree: <str(162079)> <root><template><title>short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Verizon
#   wikibase: Q467752
#   wikidata_url: https://www.wikidata.org/wiki/Q467752
#   wikitext: <str(135984)> {{short description|American telecommuni...
# }
# en.wikipedia.org (parse) Kroger
# en.wikipedia.org (imageinfo) File:Cincinnati-kroger-building.jpg
# Kroger (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Cincinnat...
#   infobox: <dict(27)> name, logo, logo_caption, image, image_size,...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:Kroger
#   pageid: 367762
#   parsetree: <str(148484)> <root><template><title>Short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Kroger
#   wikibase: Q153417
#   wikidata_url: https://www.wikidata.org/wiki/Q153417
#   wikitext: <str(122051)> {{Short description|American retail comp...
# }
# en.wikipedia.org (parse) General Electric
# General Electric (en) data
# {
#   infobox: <dict(22)> name, logo, type, predecessors, defunct, fat...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:G...
#   pageid: 12730
#   parsetree: <str(212662)> <root><template><title>short descriptio...
#   requests: <list(1)> parse
#   title: General Electric
#   wikibase: Q54173
#   wikidata_url: https://www.wikidata.org/wiki/Q54173
#   wikitext: <str(181894)> {{short description|American multination...
# }
# en.wikipedia.org (parse) Walgreens Boots Alliance
# Walgreens Boots Alliance (en) data
# {
#   infobox: <dict(23)> name, logo, type, traded_as, predecessors, f...
#   pageid: 44732533
#   parsetree: <str(38408)> <root><template><title>short description...
#   requests: <list(1)> parse
#   title: Walgreens Boots Alliance
#   wikibase: Q18712620
#   wikidata_url: https://www.wikidata.org/wiki/Q18712620
#   wikitext: <str(27704)> {{short description|American drug retail ...
# }
# en.wikipedia.org (parse) JPMorgan Chase
# en.wikipedia.org (imageinfo) File:270 Park Avenue Photomontage Day.jpg
# JPMorgan Chase (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:270 Park ...
#   infobox: <dict(26)> name, logo, image, image_caption, type, trad...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:J...
#   pageid: 231001
#   parsetree: <str(212741)> <root><template><title>Short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: JPMorgan Chase
#   wikibase: Q192314
#   wikidata_url: https://www.wikidata.org/wiki/Q192314
#   wikitext: <str(180635)> {{Short description|American multination...
# }

# %% [markdown]
# Let's take a look at the first instance in `wiki_data` i.e. **Walmart**,

# %%
wiki_data[0]
# Out:
# {'founder': '[[Sam Walton]]',
#  'location_country': 'U.S.',
#  'revenue': '{{increase}} {{US$|523.964 billion|link|=|yes}} {{small|([[Fiscal Year|FY]] 2020)}}',
#  'operating_income': '{{decrease}} {{US$|20.568 billion}} {{small|(FY 2020)}}',
#  'net_income': '{{increase}} {{US$|14.881 billion}} {{small|(FY 2020)}}',
#  'assets': '{{increase}} {{US$|236.495 billion}} {{small|(FY 2020)}}',
#  'equity': '{{increase}} {{US$|74.669 billion}} {{small|(FY 2020)}}',
#  'type': '[[Public company|Public]]',
#  'industry': '[[Retail]]',
#  'products': '{{hlist|Electronics|Movies and music|Home and furniture|Home improvement|Clothing|Footwear|Jewelry|Toys|Health and beauty|Pet supplies|Sporting goods and fitness|Auto|Photo finishing|Craft supplies|Party supplies|Grocery}}',
#  'num_employees': '{{plainlist|\n* 2.2|nbsp|million, Worldwide (2018)|ref| name="xbrlus_1" |\n* 1.5|nbsp|million, U.S. (2017)|ref| name="Walmart"|{{cite web |url = http://corporate.walmart.com/our-story/locations/united-states |title = Walmart Locations Around the World – United States |publisher = |url-status=live |archiveurl = https://web.archive.org/web/20150926012456/http://corporate.walmart.com/our-story/locations/united-states |archivedate = September 26, 2015 |df = mdy-all }}|</ref>|\n* 700,000, International}} {{nbsp}} million, Worldwide (2018) * 1.5 {{nbsp}} million, U.S. (2017) * 700,000, International',
#  'company_name': 'Walmart'}

# %% [markdown]
# So, we have successfully retrieved all the infobox data for the companies. Also we can notice that some additional wrangling and cleaning is required which we will perform in the next section.

# %% [markdown]
# Finally, let's export the scraped infoboxes as a single JSON file to a convenient location as follows,

# %%
with open('infoboxes.json', 'w') as file:
    json.dump(wiki_data, file)

# %% [markdown]
# ### References
#
# - https://phpenthusiast.com/blog/what-is-rest-api
# - https://github.com/siznax/wptools/wiki/Data-captured
# - https://en.wikipedia.org/w/api.php
# - https://wikipedia.readthedocs.io/en/latest/code.html

# %% [markdown]
# # Direct Wikipedia - Scraping

# %%
import wptools
import pandas as pd

# Print wptools version
print('wptools version : {}'.format(wptools.__version__))

# Function to get Wikipedia page information using wptools
def get_wikipedia_data(person):
    try:
        # Fetch page data for the person
        page = wptools.page(person).get_parse()

        # Extract summary, fallback to wikitext if extext is missing
        summary = page.data.get('extext', page.data.get('wikitext', 'Summary not available'))
        url = page.data.get('url', f'https://en.wikipedia.org/wiki/{person.replace(" ", "_")}')

        # Return data as a dictionary
        return {
            'name': person,
            'summary': summary[:500] + '...',  # Limit summary length for readability
            'url': url
        }
    except Exception as e:
        print(f"Error fetching data for {person}: {e}")
        return None

# Option 1: User inputs names manually (Command Line Input)
def get_input_names():
    print("Enter names (separate by comma): ")
    input_names = input().split(',')
    return [name.strip() for name in input_names]  # Strip leading/trailing spaces

# Scrape data for the input names
crypto_people = get_input_names()
crypto_data = []
for person in crypto_people:
    data = get_wikipedia_data(person)
    if data:
        crypto_data.append(data)

# Convert to DataFrame
df_crypto = pd.DataFrame(crypto_data)

# Save the DataFrame to a JSON file for later use
df_crypto.to_json('crypto_people.json', orient='records', indent=4)

# Display the DataFrame
print(df_crypto)
# Out:
# wptools version : 0.4.17
# Enter names (separate by comma):
# Vitalik Buterin
# en.wikipedia.org (parse) Vitalik Buterin
#               name                                            summary  \
# 0  Vitalik Buterin  {{Short description|Canadian programmer (born ...
#
#                                              url
# 0  https://en.wikipedia.org/wiki/Vitalik_Buterin
# en.wikipedia.org (imageinfo) File:Vitalik Buterin TechCrunch Lond...
# Vitalik Buterin (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Vitalik B...
#   infobox: <dict(13)> name, native_name, native_name_lang, image, ...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:E...
#   pageid: 41729424
#   parsetree: <str(50693)> <root><template><title>Short description...
#   requests: <list(2)> parse, imageinfo
#   title: Vitalik Buterin
#   wikibase: Q16197959
#   wikidata_url: https://www.wikidata.org/wiki/Q16197959
#   wikitext: <str(38934)> {{Short description|Canadian programmer (...
# }

# %%
df_crypto
# Out:
#               name                                            summary  \
# 0  Vitalik Buterin  {{Short description|Canadian programmer (born ...
#
#                                              url
# 0  https://en.wikipedia.org/wiki/Vitalik_Buterin

# %%
import wptools
import wikipedia
import re
from collections import Counter
import nltk
from nltk.corpus import stopwords
import pandas as pd

# Download stopwords
nltk.download('stopwords')
STOPWORDS = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Function to fetch Wikipedia data (full text)
def fetch_wikipedia_text(name):
    try:
        search_results = wikipedia.search(name)
        if len(search_results) == 0:
            print(f"No Wikipedia page found for {name}")
            return None

        correct_title = search_results[0]  # Take the first result
        page = wptools.page(correct_title).get_parse()

        if 'wikitext' in page.data:
            wikitext = page.data['wikitext']
            return wikitext
        else:
            print(f"No full text available for {name}")
            return None
    except Exception as e:
        print(f"Error fetching data for {name}: {e}")
        return None

# %%
import re

# Function to clean sentences
def clean_sentence(sentence):
    # Remove Wikipedia link syntax
    cleaned = re.sub(r'\[\[([^|\]]+)(?:\|[^\]]+)?\]\]', r'\1', sentence)  # Removes [[...]] and keeps the inner text
    # Remove patterns like |first=..., |last=..., and |url=...
    cleaned = re.sub(r'\|first=[^}]+|\|last=[^}]+|\|url=[^\s]+', '', cleaned)  # Remove |first=..., |last=..., and |url=...
    # Remove any remaining {{...}} references
    cleaned = re.sub(r'\{\{[^}]+\}\}', '', cleaned)  # Removes {{...}}
    # Remove any text starting with | and ending with space (including trailing text)
    cleaned = re.sub(r'\|[^ ]+\s*', '', cleaned)  # Remove any remaining |pattern
    # Remove leading/trailing whitespace
    return cleaned.strip()

# Example usage in your main processing loop
for line in lines:
    if line.startswith("Name:"):
        if entry:  # If entry already has data, append it to the list
            processed_data.append(entry)
            entry = {}  # Reset entry for the next item
        entry['Name'] = line.replace("Name: ", "").strip()
    elif line.startswith("Sentence:"):
        raw_sentence = line.replace("Sentence: ", "").strip()
        entry['Sentence'] = clean_sentence(raw_sentence)  # Clean the sentence
    elif line.startswith("Keywords:"):
        entry['Keywords'] = line.replace("Keywords: ", "").strip()

# %%
# Function to extract keywords from a sentence
def extract_keywords(sentence):
    words = re.findall(r'\w+', sentence.lower())
    significant_words = [word for word in words if word not in STOPWORDS and len(word) > 2]
    keyword_counts = Counter(significant_words)
    keywords = [word for word, _ in keyword_counts.most_common(3)]
    return ', '.join(keywords) if keywords else 'N/A'

# %%
# Function to write output to .txt file
def write_to_txt(output_file, data):
    with open(output_file, 'w', encoding='utf-8') as f:
        for entry in data:
            f.write(f"Name: {entry['Name']}\n")
            f.write(f"Sentence: {entry['Sentence']}\n")
            f.write(f"Keywords: {entry['Keywords']}\n")
            f.write("\n")

# %%
# Main script
input_names = input("Enter names (separate by comma): ").split(',')
input_names = [name.strip() for name in input_names]

wiki_data = []  # Renamed output_data to wiki_data

for name in input_names:
    print(f"Fetching text for {name}...")
    wikitext = fetch_wikipedia_text(name)
    if wikitext:
        sentences = split_text_into_sentences(wikitext)
        for sentence in sentences:
            keywords = extract_keywords(sentence)
            wiki_data.append({
                'Name': name,
                'Sentence': sentence,
                'Keywords': keywords
            })
# Out:
# Enter names (separate by comma): Vitalik Buterin
# Fetching text for Vitalik Buterin...
# en.wikipedia.org (parse) Vitalik Buterin
# en.wikipedia.org (imageinfo) File:Vitalik Buterin TechCrunch Lond...
# Vitalik Buterin (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Vitalik B...
#   infobox: <dict(13)> name, native_name, native_name_lang, image, ...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:E...
#   pageid: 41729424
#   parsetree: <str(50693)> <root><template><title>Short description...
#   requests: <list(2)> parse, imageinfo
#   title: Vitalik Buterin
#   wikibase: Q16197959
#   wikidata_url: https://www.wikidata.org/wiki/Q16197959
#   wikitext: <str(38934)> {{Short description|Canadian programmer (...
# }

# %%
if len(wiki_data) > 0:
    output_file = 'scraped_wikipedia_info.txt'
    write_to_txt(output_file, wiki_data)
    print(f"Data written to {output_file}")

    # Read the .txt file into a DataFrame for inspection
    with open(output_file, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # Process the lines to extract Name, Sentence, and Keywords
    processed_data = []
    entry = {}

    for line in lines:
        if line.startswith("Name:"):
            if entry:  # If entry already has data, append it to the list
                processed_data.append(entry)
                entry = {}  # Reset entry for the next item
            entry['Name'] = line.replace("Name: ", "").strip()
        elif line.startswith("Sentence:"):
            entry['Sentence'] = line.replace("Sentence: ", "").strip()
        elif line.startswith("Keywords:"):
            entry['Keywords'] = line.replace("Keywords: ", "").strip()

    # Append the last entry if it exists
    if entry:
        processed_data.append(entry)

    # Convert processed data to DataFrame
    df = pd.DataFrame(processed_data)

    # Display the DataFrame
    print(df)
# Out:
# Data written to scraped_wikipedia_info.txt
#                Name                                           Sentence  \
# 0   Vitalik Buterin  {{Short description|Canadian programmer (born ...
# 1   Vitalik Buterin  What a beautiful messy complicated journey is ...
# 2   Vitalik Buterin  Buterin became involved with [[cryptocurrency]...
# 3   Vitalik Buterin  |title=The Man Behind Ethereum Is Worried Abou...
# 4   Vitalik Buterin  There, he took advanced courses and was a rese...
# 5   Vitalik Buterin  He returned to Toronto later that year and pub...
# 6   Vitalik Buterin                                                -->
# 7   Vitalik Buterin  But when he failed to gain agreement, he propo...
# 8   Vitalik Buterin  Buterin announced Ethereum more publicly at th...
# 9   Vitalik Buterin  Buterin delivered a 25-minute speech, describi...
# 10  Vitalik Buterin  111 --> operating on a decentralized permissio...
# 11  Vitalik Buterin  He's not too excited that the community assign...
# 12  Vitalik Buterin  He wants the community to be more resilient."<...
# 13  Vitalik Buterin  I cried myself to sleep, and on that day I rea...
# 14  Vitalik Buterin  I soon decided to quit.<ref>{{cite magazine |l...
# 15  Vitalik Buterin                                      |chapter= #4.
# 16  Vitalik Buterin  Keys, Addresses, and Wallets |page= 82 |isbn= ...
# 17  Vitalik Buterin  Putin stated that he "supported the idea of es...
# 18  Vitalik Buterin                      Retrieved 20 July 2018.</ref>
# 19  Vitalik Buterin  The paper sets out a method for optimal provis...
# 20  Vitalik Buterin  |url=https://unblock.net/who-is-vitalik-buteri...
# 21  Vitalik Buterin  Together with [[Sam Bankman-Fried]] and Haseeb...
# 22  Vitalik Buterin  On the first day of the invasion, Buterin twee...
# 23  Vitalik Buterin  |first=Vitalik |last=Buterin}}</ref><ref>{{Cit...
# 24  Vitalik Buterin  Это преступление против украинского и русского...
# 25  Vitalik Buterin  |first=Vitalik |last=Buterin |trans-title=Very...
# 26  Vitalik Buterin  This is a crime against the Ukrainian and Russ...
# 27  Vitalik Buterin  |lang=ru}}</ref><ref>{{Cite news |date=27 Febr...
# 28  Vitalik Buterin  She had claimed that people who said they were...
# 29  Vitalik Buterin  These include [[Ukraine DAO]],<ref>{{Cite twee...
# 30  Vitalik Buterin  |first=Vitalik |last=Buterin}}</ref><ref>{{Cit...
# 31  Vitalik Buterin  |date=27 February 2022 |title=Binance Announce...
# 32  Vitalik Buterin                     His dad is even more involved.
# 33  Vitalik Buterin  |url=https://fortune.com/2022/03/31/ukraine-da...
# 34  Vitalik Buterin  ''Proof of Stake: The Making of Ethereum and t...
# 35  Vitalik Buterin                   — [[Seven Stories Press]], 2022.
# 36  Vitalik Buterin                                               — С.
# 37  Vitalik Buterin                                               384.
# 38  Vitalik Buterin                             — ISBN 978-1644212486.
# 39  Vitalik Buterin
#
#                          Keywords
# 0   buterin, vitalik, dmitrievich
# 1          human, date, beautiful
# 2                 ref, url, https
# 3              date, url, buterin
# 4               archive, url, www
# 5           buterin, archive, url
# 6          ethereum, archive, url
# 7              new, ref, tapscott
# 8       miami, buterin, announced
# 9      buterin, delivered, minute
# 10       2020, ref, decentralized
# 11    excited, community, assigns
# 12      world, warcraft, blizzard
# 13              cried, sleep, day
# 14                ref, url, https
# 15                        chapter
# 16               books, date, url
# 17           russian, 2017, https
# 18               weyl, url, https
# 19                ref, https, web
# 20                2018, date, url
# 21               2021, url, https
# 22       ethereum, neutral, first
# 23               ref, first, last
# 24      это, преступление, против
# 25           first, vitalik, last
# 26      crime, ukrainian, russian
# 27             ref, lang, ukraine
# 28     russians, ukraine, русские
# 29   ukrainians, include, ukraine
# 30               first, last, ref
# 31    announces, million, ukraine
# 32            dad, even, involved
# 33           2022, https, fortune
# 34           proof, stake, making
# 35          seven, stories, press
# 36                            N/A
# 37                            384
# 38          isbn, 978, 1644212486
# 39             url, date, archive

# %%
df
# Out:
#                Name                                           Sentence  \
# 0   Vitalik Buterin  {{Short description|Canadian programmer (born ...
# 1   Vitalik Buterin  What a beautiful messy complicated journey is ...
# 2   Vitalik Buterin  Buterin became involved with [[cryptocurrency]...
# 3   Vitalik Buterin  |title=The Man Behind Ethereum Is Worried Abou...
# 4   Vitalik Buterin  There, he took advanced courses and was a rese...
# 5   Vitalik Buterin  He returned to Toronto later that year and pub...
# 6   Vitalik Buterin                                                -->
# 7   Vitalik Buterin  But when he failed to gain agreement, he propo...
# 8   Vitalik Buterin  Buterin announced Ethereum more publicly at th...
# 9   Vitalik Buterin  Buterin delivered a 25-minute speech, describi...
# 10  Vitalik Buterin  111 --> operating on a decentralized permissio...
# 11  Vitalik Buterin  He's not too excited that the community assign...
# 12  Vitalik Buterin  He wants the community to be more resilient."<...
# 13  Vitalik Buterin  I cried myself to sleep, and on that day I rea...
# 14  Vitalik Buterin  I soon decided to quit.<ref>{{cite magazine |l...
# 15  Vitalik Buterin                                      |chapter= #4.
# 16  Vitalik Buterin  Keys, Addresses, and Wallets |page= 82 |isbn= ...
# 17  Vitalik Buterin  Putin stated that he "supported the idea of es...
# 18  Vitalik Buterin                      Retrieved 20 July 2018.</ref>
# 19  Vitalik Buterin  The paper sets out a method for optimal provis...
# 20  Vitalik Buterin  |url=https://unblock.net/who-is-vitalik-buteri...
# 21  Vitalik Buterin  Together with [[Sam Bankman-Fried]] and Haseeb...
# 22  Vitalik Buterin  On the first day of the invasion, Buterin twee...
# 23  Vitalik Buterin  |first=Vitalik |last=Buterin}}</ref><ref>{{Cit...
# 24  Vitalik Buterin  Это преступление против украинского и русского...
# 25  Vitalik Buterin  |first=Vitalik |last=Buterin |trans-title=Very...
# 26  Vitalik Buterin  This is a crime against the Ukrainian and Russ...
# 27  Vitalik Buterin  |lang=ru}}</ref><ref>{{Cite news |date=27 Febr...
# 28  Vitalik Buterin  She had claimed that people who said they were...
# 29  Vitalik Buterin  These include [[Ukraine DAO]],<ref>{{Cite twee...
# 30  Vitalik Buterin  |first=Vitalik |last=Buterin}}</ref><ref>{{Cit...
# 31  Vitalik Buterin  |date=27 February 2022 |title=Binance Announce...
# 32  Vitalik Buterin                     His dad is even more involved.
# 33  Vitalik Buterin  |url=https://fortune.com/2022/03/31/ukraine-da...
# 34  Vitalik Buterin  ''Proof of Stake: The Making of Ethereum and t...
# 35  Vitalik Buterin                   — [[Seven Stories Press]], 2022.
# 36  Vitalik Buterin                                               — С.
# 37  Vitalik Buterin                                               384.
# 38  Vitalik Buterin                             — ISBN 978-1644212486.
# 39  Vitalik Buterin
#
#                          Keywords
# 0   buterin, vitalik, dmitrievich
# 1          human, date, beautiful
# 2                 ref, url, https
# 3              date, url, buterin
# 4               archive, url, www
# 5           buterin, archive, url
# 6          ethereum, archive, url
# 7              new, ref, tapscott
# 8       miami, buterin, announced
# 9      buterin, delivered, minute
# 10       2020, ref, decentralized
# 11    excited, community, assigns
# 12      world, warcraft, blizzard
# 13              cried, sleep, day
# 14                ref, url, https
# 15                        chapter
# 16               books, date, url
# 17           russian, 2017, https
# 18               weyl, url, https
# 19                ref, https, web
# 20                2018, date, url
# 21               2021, url, https
# 22       ethereum, neutral, first
# 23               ref, first, last
# 24      это, преступление, против
# 25           first, vitalik, last
# 26      crime, ukrainian, russian
# 27             ref, lang, ukraine
# 28     russians, ukraine, русские
# 29   ukrainians, include, ukraine
# 30               first, last, ref
# 31    announces, million, ukraine
# 32            dad, even, involved
# 33           2022, https, fortune
# 34           proof, stake, making
# 35          seven, stories, press
# 36                            N/A
# 37                            384
# 38          isbn, 978, 1644212486
# 39             url, date, archive
